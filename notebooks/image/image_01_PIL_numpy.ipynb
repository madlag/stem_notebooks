# %%
import numpy

# %%
from scipy import ndimage

# %%
from scipy import misc
f = misc.face()

# %%
import matplotlib.pyplot as plt
def display(img):
    plt.imshow(img) 
    plt.show()

# %%
f.shape
# Out:
# (768, 1024, 3)

# %%
display(f)

# %%
f2=f//2

# %%
display(f2)

# %%
print(f[0][0])
# Out:
# [121 112 131]

# %%
print(f2[0][0])
# Out:
# [60 56 65]

# %%
f3=numpy.array(f)
f3[:,:,1]=f3[:,:,0]*f3[:,:,1]//255
#f3[:,:,1]=0

# %%
display(f3)

# %%
f3.shape
# Out:
# (768, 1024, 3)

# %%
f.shape
# Out:
# (768, 1024, 3)

# %%
from PIL import Image, ImageDraw
s=list(f.shape[:2])
s.reverse()
background=(70,) *3
im = Image.new('RGB', s, background)

draw = ImageDraw.Draw(im)
x=f.shape[1]
y=f.shape[0]
draw.ellipse([(x-y, 0), im.size], fill=(255,255,255,255), outline=None)

# %%
display(im)

# %%
mask=numpy.array(im)/255

# %%
mask.min(), mask.max()
# Out:
# (0.27450980392156865, 1.0)

# %%
mask.shape
# Out:
# (768, 1024, 3)

# %%
f4=(f * mask).astype("ubyte")

# %%
display(f4)

# %%
f4.min(),f4.max()
# Out:
# (0, 255)
